# %%
import json

def load_json(file_path):
    """
    Load a JSON file and return its content as a Python dictionary.

    :param file_path: Path to the JSON file.
    :return: Dictionary containing the JSON data.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# %%
data = load_json('../data/MC3_graph.json')
schema = load_json('../data/MC3_schema.json')

# %%
data
# Out:
# {'directed': True,
#  'multigraph': False,
#  'graph': {'mode': 'static',
#   'edge_default': {},
#   'node_default': {},
#   'name': 'VAST_MC3_Knowledge_Graph'},
#  'nodes': [{'type': 'Entity',
#    'label': 'Sam',
#    'name': 'Sam',
#    'sub_type': 'Person',
#    'id': 'Sam'},
#   {'type': 'Entity',
#    'label': 'Kelly',
#    'name': 'Kelly',
#    'sub_type': 'Person',
#    'id': 'Kelly'},
#   {'type': 'Entity',
#    'label': 'Nadia Conti',
#    'name': 'Nadia Conti',
#    'sub_type': 'Person',
#    'id': 'Nadia Conti'},
#   {'type': 'Entity',
#    'label': 'Elise',
#    'name': 'Elise',
#    'sub_type': 'Person',
#    'id': 'Elise'},
#   {'type': 'Entity',
#    'label': 'Liam Thorne',
#    'name': 'Liam Thorne',
#    'sub_type': 'Person',
#    'id': 'Liam Thorne'},
#   {'type': 'Entity',
#    'label': 'Samantha Blake',
#    'name': 'Samantha Blake',
#    'sub_type': 'Person',
#    'id': 'Samantha Blake'},
#   {'type': 'Entity',
#    'label': 'Davis',
#    'name': 'Davis',
#    'sub_type': 'Person',
#    'id': 'Davis'},
#   {'type': 'Entity',
#    'label': 'Rodriguez',
#    'name': 'Rodriguez',
#    'sub_type': 'Person',
#    'id': 'Rodriguez'},
#   {'type': 'Entity',
#    'label': 'Sailor Shift',
#    'name': 'Sailor Shift',
#    'sub_type': 'Person',
#    'id': 'Sailor Shift'},
#   {'type': 'Entity',
#    'label': 'Clepper Jensen',
#    'name': 'Clepper Jensen',
#    'sub_type': 'Person',
#    'id': 'Clepper Jensen'},
#   {'type': 'Entity',
#    'label': 'Miranda Jordan',
#    'name': 'Miranda Jordan',
#    'sub_type': 'Person',
#    'id': 'Miranda Jordan'},
#   {'type': 'Entity',
#    'label': 'The Intern',
#    'name': 'The Intern',
#    'sub_type': 'Person',
#    'id': 'The Intern'},
#   {'type': 'Entity',
#    'label': 'The Lookout',
#    'name': 'The Lookout',
#    'sub_type': 'Person',
#    'id': 'The Lookout'},
#   {'type': 'Entity',
#    'label': 'The Accountant',
#    'name': 'The Accountant',
#    'sub_type': 'Person',
#    'id': 'The Accountant'},
#   {'type': 'Entity',
#    'label': 'Mrs. Money',
#    'name': 'Mrs. Money',
#    'sub_type': 'Person',
#    'id': 'Mrs. Money'},
#   {'type': 'Entity',
#    'label': 'The Middleman',
#    'name': 'The Middleman',
#    'sub_type': 'Person',
#    'id': 'The Middleman'},
#   {'type': 'Entity',
#    'label': 'Boss',
#    'name': 'Boss',
#    'sub_type': 'Person',
#    'id': 'Boss'},
#   {'type': 'Entity',
#    'label': 'Small Fry',
#    'name': 'Small Fry',
#    'sub_type': 'Person',
#    'id': 'Small Fry'},
#   {'type': 'Entity',
#    'label': 'Glitters Team',
#    'name': 'Glitters Team',
#    'sub_type': 'Organization',
#    'id': 'Glitters Team'},
#   {'type': 'Entity',
#    'label': 'Oceanus City Council',
#    'name': 'Oceanus City Council',
#    'sub_type': 'Organization',
#    'id': 'Oceanus City Council'},
#   {'type': 'Entity',
#    'label': 'Green Guardians',
#    'name': 'Green Guardians',
#    'sub_type': 'Organization',
#    'id': 'Green Guardians'},
#   {'type': 'Entity',
#    'label': 'V. Miesel Shipping',
#    'name': 'V. Miesel Shipping',
#    'sub_type': 'Organization',
#    'id': 'V. Miesel Shipping'},
#   {'type': 'Entity',
#    'label': 'Sailor Shifts Team',
#    'name': 'Sailor Shifts Team',
#    'sub_type': 'Organization',
#    'id': 'Sailor Shifts Team'},
#   {'type': 'Entity',
#    'label': 'Neptune',
#    'name': 'Neptune',
#    'sub_type': 'Vessel',
#    'id': 'Neptune'},
#   {'type': 'Entity',
#    'label': 'Marlin',
#    'name': 'Marlin',
#    'sub_type': 'Vessel',
#    'id': 'Marlin'},
#   {'type': 'Entity',
#    'label': 'Serenity',
#    'name': 'Serenity',
#    'sub_type': 'Vessel',
#    'id': 'Serenity'},
#   {'type': 'Entity',
#    'label': 'Mako',
#    'name': 'Mako',
#    'sub_type': 'Vessel',
#    'id': 'Mako'},
#   {'type': 'Entity',
#    'label': 'Reef Guardian',
#    'name': 'Reef Guardian',
#    'sub_type': 'Vessel',
#    'id': 'Reef Guardian'},
#   {'type': 'Entity',
#    'label': 'Horizon',
#    'name': 'Horizon',
#    'sub_type': 'Vessel',
#    'id': 'Horizon'},
#   {'type': 'Entity',
#    'label': 'Seawatch',
#    'name': 'Seawatch',
#    'sub_type': 'Vessel',
#    'id': 'Seawatch'},
#   {'type': 'Entity',
#    'label': 'EcoVigil',
#    'name': 'EcoVigil',
#    'sub_type': 'Vessel',
#    'id': 'EcoVigil'},
#   {'type': 'Entity',
#    'label': 'Sentinel',
#    'name': 'Sentinel',
#    'sub_type': 'Vessel',
#    'id': 'Sentinel'},
#   {'type': 'Entity',
#    'label': 'Osprey',
#    'name': 'Osprey',
#    'sub_type': 'Vessel',
#    'id': 'Osprey'},
#   {'type': 'Entity',
#    'label': 'Defender',
#    'name': 'Defender',
#    'sub_type': 'Vessel',
#    'id': 'Defender'},
#   {'type': 'Entity',
#    'label': 'Northern Light',
#    'name': 'Northern Light',
#    'sub_type': 'Vessel',
#    'id': 'Northern Light'},
#   {'type': 'Entity',
#    'label': 'Remora',
#    'name': 'Remora',
#    'sub_type': 'Vessel',
#    'id': 'Remora'},
#   {'type': 'Entity',
#    'label': 'Knowles',
#    'name': 'Knowles',
#    'sub_type': 'Vessel',
#    'id': 'Knowles'},
#   {'type': 'Entity',
#    'label': "Mariner's Dream",
#    'name': "Mariner's Dream",
#    'sub_type': 'Vessel',
#    'id': "Mariner's Dream"},
#   {'type': 'Entity',
#    'label': 'Recreational Fishing Boats',
#    'name': 'Recreational Fishing Boats',
#    'sub_type': 'Group',
#    'id': 'Recreational Fishing Boats'},
#   {'type': 'Entity',
#    'label': 'City Officials',
#    'name': 'City Officials',
#    'sub_type': 'Group',
#    'id': 'City Officials'},
#   {'type': 'Entity',
#    'label': 'Diving Tour Operators',
#    'name': 'Diving Tour Operators',
#    'sub_type': 'Group',
#    'id': 'Diving Tour Operators'},
#   {'type': 'Entity',
#    'label': 'Tourists',
#    'name': 'Tourists',
#    'sub_type': 'Group',
#    'id': 'Tourists'},
#   {'type': 'Entity',
#    'label': 'Conservation Vessels',
#    'name': 'Conservation Vessels',
#    'sub_type': 'Group',
#    'id': 'Conservation Vessels'},
#   {'type': 'Entity',
#    'label': 'Paackland Harbor',
#    'name': 'Paackland Harbor',
#    'sub_type': 'Location',
#    'id': 'Paackland Harbor'},
#   {'type': 'Entity',
#    'label': 'Haacklee Harbor',
#    'name': 'Haacklee Harbor',
#    'sub_type': 'Location',
#    'id': 'Haacklee Harbor'},
#   {'type': 'Entity',
#    'label': 'Himark Harbor',
#    'name': 'Himark Harbor',
#    'sub_type': 'Location',
#    'id': 'Himark Harbor'},
#   {'type': 'Entity',
#    'label': 'Nemo Reef',
#    'name': 'Nemo Reef',
#    'sub_type': 'Location',
#    'id': 'Nemo Reef'},
#   {'type': 'Entity',
#    'label': 'Restricted areas',
#    'name': 'Restricted areas',
#    'sub_type': 'Location',
#    'id': 'Restricted areas'},
#   {'type': 'Entity',
#    'label': 'Azure Cove',
#    'name': 'Azure Cove',
#    'sub_type': 'Location',
#    'id': 'Azure Cove'},
#   {'type': 'Entity',
#    'label': 'Protected areas',
#    'name': 'Protected areas',
#    'sub_type': 'Location',
#    'id': 'Protected areas'},
#   {'type': 'Entity',
#    'label': 'Eastern reefs',
#    'name': 'Eastern reefs',
#    'sub_type': 'Location',
#    'id': 'Eastern reefs'},
#   {'type': 'Entity',
#    'label': 'Eastern Coastline',
#    'name': 'Eastern Coastline',
#    'sub_type': 'Location',
#    'id': 'Eastern Coastline'},
#   {'type': 'Entity',
#    'label': 'Southern islands',
#    'name': 'Southern islands',
#    'sub_type': 'Location',
#    'id': 'Southern islands'},
#   {'type': 'Entity',
#    'label': 'Southern coastline',
#    'name': 'Southern coastline',
#    'sub_type': 'Location',
#    'id': 'Southern coastline'},
#   {'type': 'Entity',
#    'label': 'Coral Point',
#    'name': 'Coral Point',
#    'sub_type': 'Location',
#    'id': 'Coral Point'},
#   {'type': 'Entity',
#    'label': 'Dolphin Bay',
#    'name': 'Dolphin Bay',
#    'sub_type': 'Location',
#    'id': 'Dolphin Bay'},
#   {'type': 'Entity',
#    'label': 'E7',
#    'name': 'E7',
#    'sub_type': 'Location',
#    'id': 'E7'},
#   {'type': 'Entity',
#    'label': 'Northern quadrant',
#    'name': 'Northern quadrant',
#    'sub_type': 'Location',
#    'id': 'Northern quadrant'},
#   {'type': 'Entity',
#    'label': 'Southern quadrant',
#    'name': 'Southern quadrant',
#    'sub_type': 'Location',
#    'id': 'Southern quadrant'},
#   {'type': 'Entity',
#    'label': 'Eastern quadrant',
#    'name': 'Eastern quadrant',
#    'sub_type': 'Location',
#    'id': 'Eastern quadrant'},
#   {'type': 'Entity',
#    'label': 'Western quadrant',
#    'name': 'Western quadrant',
#    'sub_type': 'Location',
#    'id': 'Western quadrant'},
#   {'type': 'Entity',
#    'label': 'Eastern Islands',
#    'name': 'Eastern Islands',
#    'sub_type': 'Location',
#    'id': 'Eastern Islands'},
#   {'type': 'Entity',
#    'label': 'Western Boundary',
#    'name': 'Western Boundary',
#    'sub_type': 'Location',
#    'id': 'Western Boundary'},
#   {'type': 'Entity',
#    'label': 'Eastern Boundary',
#    'name': 'Eastern Boundary',
#    'sub_type': 'Location',
#    'id': 'Eastern Boundary'},
#   {'type': 'Entity',
#    'label': 'Southern Boundary',
#    'name': 'Southern Boundary',
#    'sub_type': 'Location',
#    'id': 'Southern Boundary'},
#   {'type': 'Entity',
#    'label': 'Eastern Shoals',
#    'name': 'Eastern Shoals',
#    'sub_type': 'Location',
#    'id': 'Eastern Shoals'},
#   {'type': 'Entity',
#    'label': 'Restricted Zone',
#    'name': 'Restricted Zone',
#    'sub_type': 'Location',
#    'id': 'Restricted Zone'},
#   {'type': 'Entity',
#    'label': 'Route C',
#    'name': 'Route C',
#    'sub_type': 'Location',
#    'id': 'Route C'},
#   {'type': 'Entity',
#    'label': 'South Dock',
#    'name': 'South Dock',
#    'sub_type': 'Location',
#    'id': 'South Dock'},
#   {'type': 'Entity',
#    'label': 'Castaway Cove',
#    'name': 'Castaway Cove',
#    'sub_type': 'Location',
#    'id': 'Castaway Cove'},
#   {'type': 'Entity',
#    'label': 'Berth 14',
#    'name': 'Berth 14',
#    'sub_type': 'Location',
#    'id': 'Berth 14'},
#   {'type': 'Entity',
#    'label': 'Port Security',
#    'name': 'Port Security',
#    'sub_type': 'Location',
#    'id': 'Port Security'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 08:09:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'A pod of dolphins was spotted near the eastern point this morning. They were playful. Migratory birds are starting to arrive.',
#    'id': 'Event_Monitoring_0'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 10:48:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Increased tourism vessel activity near protected areas, specifically Nemo Reef.',
#    'id': 'Event_Monitoring_33'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': None,
#    'monitoring_type': 'surveillance',
#    'findings': 'increased vessel activity at Nemo Reef',
#    'id': 'Event_Monitoring_38'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 11:40:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Increased tourism vessel activity near protected areas, especially around Nemo Reef',
#    'id': 'Event_Monitoring_60'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:34:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increased tourism vessel activity near Nemo Reef. Inconsistent enforcement noted. Water quality report to be sent separately.',
#    'id': 'Event_Monitoring_68'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:37:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increased tourism activity near protected areas, particularly Nemo Reef. Coordination with Sentinel on western boundary requested. Extra patrols needed for two weeks.',
#    'id': 'Event_Monitoring_71'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:39:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increased tourism near Nemo Reef. Horizon monitoring eastern boundary, Sentinel taking western boundary.',
#    'id': 'Event_Monitoring_73'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:39:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increased tourism reported near Nemo Reef. Horizon will monitor eastern boundary while Sentinel takes western boundary. Will document violations and compare notes at 1800 hours.',
#    'id': 'Event_Monitoring_74'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:40:00',
#    'monitoring_type': 'patrol activity',
#    'findings': "Three tourism vessels approaching Nemo Reef's protected zones in the last hour",
#    'id': 'Event_Monitoring_77'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 12:44:00',
#    'monitoring_type': 'patrol activity',
#    'findings': "Multiple tourism vessels crossing protected zones around Nemo Reef's southern boundary",
#    'id': 'Event_Monitoring_83'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-02 09:59:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Multiple protected zone violations at Nemo Reef',
#    'id': 'Event_Monitoring_105'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-02 12:16:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Three vessels (two commercial and one private yacht) repeatedly circling Nemo Reef. Permit application filed by Rodriguez from 'Sailor Shifts Team' requesting access for 'environmental sampling'.",
#    'id': 'Event_Monitoring_129'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-02 12:22:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Rodriguez is connected to a mining consortium with previous violations in protected areas. Their equipment appears designed for core sampling, not environmental research.',
#    'id': 'Event_Monitoring_133'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-01 00:00:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Request for information about tourism vessels approaching Nemo Reef for conservation monitoring purposes',
#    'id': 'Event_Monitoring_148'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 08:35:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increasing patrol frequency around Nemo Reef after reports of tourism vessels offering unauthorized access.',
#    'id': 'Event_Monitoring_164'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 08:39:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Increased patrols around Nemo Reef due to reports of tourism vessels offering unauthorized access for payment',
#    'id': 'Event_Monitoring_168'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 08:44:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Five unauthorized tourism vessels near Nemo Reef. Concerning pattern emerging. Some operators may be attempting to circumvent restrictions.',
#    'id': 'Event_Monitoring_173'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 09:12:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Observed Mariner's Dream making suspicious approaches to restricted areas. Sentinel is moving to intercept.",
#    'id': 'Event_Monitoring_192'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 10:02:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Additional night-vision equipment will be brought for 24-hour surveillance. Setup will take approximately 60 minutes. Patterns in unauthorized entries are being investigated.',
#    'id': 'Event_Monitoring_208'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-03 10:38:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Northern Light vessel reports uneven enforcement, claiming tourism boats enter restricted zones without consequences while commercial vessels are fined for minor infractions',
#    'id': 'Event_Monitoring_232'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-04 08:03:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Mako vessel approaching Nemo Reef protected area with conservation boats following them',
#    'id': 'Event_Monitoring_243'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-04 08:38:00',
#    'monitoring_type': 'water quality testing',
#    'findings': 'Mako conducting authorized water quality sampling near Echo-7 marker for Oceanus Environmental Department',
#    'id': 'Event_Monitoring_253'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-04 08:41:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Mako confirmed near Echo-7 marker, conducting authorized water quality sampling for Oceanus Environmental, promising to stay outside protected boundaries',
#    'id': 'Event_Monitoring_255'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-04 09:13:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Vessel with transponder name 'Mako' detected near Nemo Reef protected boundary before signal loss",
#    'id': 'Event_Monitoring_266'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-04 11:04:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Mako taking an unusual route with proximity to Nemo Reef's eastern boundary",
#    'id': 'Event_Monitoring_286'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-05 10:30:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Positioned near V. Miesel equipment loading. Transfer of specialized drilling machinery with deep-sea modifications observed. Serial numbers documented. Potentially unauthorized marine survey equipment spotted.',
#    'id': 'Event_Monitoring_358'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-06 09:50:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Planning to establish full monitoring protocol at Nemo Reef to document vessel activities, equipment, and personnel. Coordinating with Horizon and Sentinel for continuous coverage. Something expected to happen tomorrow.',
#    'id': 'Event_Monitoring_383'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-06 11:46:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Construction crews arrived today for site preparation at Nemo Reef. Equipment installation scheduled tomorrow with full event execution next week. Expedited approval after previous denial suggests concerning influence.',
#    'id': 'Event_Monitoring_410'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-06 12:24:00',
#    'monitoring_type': 'water quality testing',
#    'findings': 'Preparing water sampling kits for deployment and planning to bring satellite tracking equipment to monitor vessels potentially violating protected zones',
#    'id': 'Event_Monitoring_414'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-07 08:14:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Lookout provided photos of the fragile crates at harbor. Neptune's using unusual loading equipment. V. Miesel shipping lanes appear to overlap with new Mako corridors by 40%.",
#    'id': 'Event_Monitoring_444'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-07 10:33:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Reef Guardian sentinel repositioning to southern boundary. Neptune involvement noted as concerning. Will be tracking transfers and equipment movements.',
#    'id': 'Event_Monitoring_484'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-07 10:37:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Neptune's equipment claims check out - imaging devices and dive gear at eastern markers. Something still feels off about this operation.",
#    'id': 'Event_Monitoring_490'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-08 08:21:00',
#    'monitoring_type': 'patrol activity',
#    'findings': "Harbor patrols confirm Mako's environmental sampling is legitimate. Increased vessel activity from V. Miesel Shipping near the reef documented.",
#    'id': 'Event_Monitoring_530'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': None,
#    'monitoring_type': 'patrol activity',
#    'findings': 'Patrol schedules have been redirected/modified to work in favor of the message sender and recipient',
#    'id': 'Event_Monitoring_534'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-09 08:12:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Specialized underwater concrete forms discovered in fragile crates. Harbor master mentioned 'deep water construction' multiple times, suggesting permanent structures at Nemo Reef beyond equipment installation.",
#    'id': 'Event_Monitoring_595'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-09 10:20:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Identified unauthorized deep-sea extraction equipment at Nemo Reef. Multiple executive personnel supervising from distance. Documenting evidence of container transfers between Neptune's team and unmarked civilian vessels.",
#    'id': 'Event_Monitoring_608'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-09 10:44:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'increased vessel activity for Nemo Reef operations',
#    'id': 'Event_Monitoring_631'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 09:32:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Container vessels observed at northwest perimeter (24°15'N, 81°48'W) loading coral samples and seabed materials.",
#    'id': 'Event_Monitoring_661'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 10:47:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Suspicious industrial equipment deliveries contradicting environmental closure claims observed around Nemo Reef',
#    'id': 'Event_Monitoring_678'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 11:23:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Planning increased night patrols at eastern boundary markers due to information about tourism vessels',
#    'id': 'Event_Monitoring_688'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 11:24:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Suspicious extraction activities and industrial equipment deliveries contradicting environmental closure claims at Nemo Reef',
#    'id': 'Event_Monitoring_690'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 05:00:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Evidence of concrete structures, V. Miesel's expansion plans, and unusual movement in the harbor",
#    'id': 'Event_Monitoring_704'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-10 21:00:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Patrol of eastern quadrant scheduled. Night vision systems operational. Seeking vessel registration numbers for documentation.',
#    'id': 'Event_Monitoring_709'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-11 08:07:00',
#    'monitoring_type': 'water quality testing',
#    'findings': 'Two conservation vessels anchoring north of Nemo Reef using sonar equipment and taking water samples. Rare osprey spotted.',
#    'id': 'Event_Monitoring_716'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': None,
#    'monitoring_type': 'patrol activity',
#    'findings': 'nothing found at Nemo Reef',
#    'id': 'Event_Monitoring_722'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-11 09:20:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'EcoVigil questioning ROV delay, showing interest in Western quadrant while being redirected to northern quadrant',
#    'id': 'Event_Monitoring_752'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-11 10:09:00',
#    'monitoring_type': 'surveillance',
#    'findings': "Equipment labeled 'Project Poseidon: Resource Extraction Phase'. Conservation vessels conducting environmental surveys but restricted from certain areas.",
#    'id': 'Event_Monitoring_766'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-11 10:38:00',
#    'monitoring_type': 'water quality testing',
#    'findings': 'Completed extensive sampling near Nemo Reef. Preliminary findings show normal water quality parameters with no significant environmental hazards detected. Full analysis available within hours.',
#    'id': 'Event_Monitoring_777'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-12 08:59:00',
#    'monitoring_type': 'surveillance',
#    'findings': '12 vessels in east quadrant with heavy drilling equipment. Registration numbers documented.',
#    'id': 'Event_Monitoring_797'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-12 09:24:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Davis Rodriguez maintaining position with Mako at Nemo Reef. Operating under permit #CR-7844 while maintaining tourism appearance. Security team expected to arrive at 0600.',
#    'id': 'Event_Monitoring_803'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-12 10:55:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Documented vessel registrations show 7 unregistered boats at Nemo Reef. Equipment includes seabed drills and extraction pumps - clear mining preparation.',
#    'id': 'Event_Monitoring_829'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-12 11:02:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'evidence of unregistered vessels and mining equipment',
#    'id': 'Event_Monitoring_835'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-12 12:59:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Reef Guardian covering southeast quadrant for surveillance, requesting information about Port Authority vessel encounters for protest documentation',
#    'id': 'Event_Monitoring_856'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 09:08:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Detected multiple transmission clusters near west reef edge. Recording frequency patterns of encrypted communications. Able to triangulate source vessels.',
#    'id': 'Event_Monitoring_878'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 12:22:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Unauthorized activity at Nemo Reef during closure - encrypted communications, equipment transfers, and fuel contamination',
#    'id': 'Event_Monitoring_900'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 12:34:00',
#    'monitoring_type': 'water quality testing',
#    'findings': 'Need to gather additional evidence at Nemo Reef, including water sample collection and documenting vessel movements',
#    'id': 'Event_Monitoring_909'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 12:36:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Spotted what appears to be a music video shoot with lighting rigs and camera equipment on west reef. Unable to confirm details due to distance.',
#    'id': 'Event_Monitoring_911'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 12:41:00',
#    'monitoring_type': 'patrol activity',
#    'findings': 'Unauthorized activity at Nemo Reef during closure, requiring patrol of western boundary to document vessel movements and equipment transfers',
#    'id': 'Event_Monitoring_917'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 07:00:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Conservation vessels moving equipment to the eastern side of Nemo Reef',
#    'id': 'Event_Monitoring_922'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 13:20:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'EcoVigil positioning required. Western quadrant to remain completely restricted for 48 hours. Unauthorized conservation vessels near restricted zones to be monitored.',
#    'id': 'Event_Monitoring_929'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-13 13:23:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Western quadrant restriction confirmed for 48 hours. EcoVigil redirected north as instructed. Unauthorized vessel monitoring in place.',
#    'id': 'Event_Monitoring_932'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 08:06:00',
#    'monitoring_type': 'drone surveillance',
#    'findings': 'Conservation vessels deploying drones with cameras over Nemo Reef',
#    'id': 'Event_Monitoring_934'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 08:34:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Conservation vessels being monitored. Delta-3 protocols active, tourism facade maintained.',
#    'id': 'Event_Monitoring_941'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 08:34:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Conservation vessels being monitored. Delta-3 protocols active, tourism facade maintained.',
#    'id': 'Event_Monitoring_942'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 08:40:00',
#    'monitoring_type': 'drone surveillance',
#    'findings': 'Port Authority blocking approach to Nemo Reef, requesting aerial drone documentation of activities during closure',
#    'id': 'Event_Monitoring_946'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 09:04:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Operation proceeding as planned. Equipment transfer completed at south dock. Maintaining tourism facade successfully. Need authorization for additional fuel allocation due to extended perimeter monitoring.',
#    'id': 'Event_Monitoring_957'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 10:58:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Music video shoot occurring with potential environmental impact and permit violations. Green Guardians HQ confirming need to investigate and continue monitoring water contamination levels.',
#    'id': 'Event_Monitoring_967'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 11:32:00',
#    'monitoring_type': 'drone surveillance',
#    'findings': 'Port Authority blocking approach to Nemo Reef. Attempting to coordinate with Sentinel for documentation. Need aerial footage of equipment and activities at Nemo Reef.',
#    'id': 'Event_Monitoring_971'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 11:37:00',
#    'monitoring_type': 'surveillance',
#    'findings': 'Video production underway at Nemo Reef with performers, lighting rigs, and filming equipment visible. No environmental assessment was conducted before this commercial activity.',
#    'id': 'Event_Monitoring_978'},
#   {'type': 'Event',
#    'sub_type': 'Monitoring',
#    'label': 'Monitoring',
#    'timestamp': '2040-10-14 12:51:00',
#    'monitoring_type': 'miscellaneous monitoring',
#    'findings': 'Video evidence collected of environmental impacts at Nemo Reef, with ongoing monitoring for cleanup efforts as vessels depart',
#    'id': 'Event_Monitoring_995'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:09:00',
#    'content': "Hey The Intern, it's The Lookout! Just spotted a pod of dolphins near the eastern point this morning. They were so playful! If you're free this weekend, the migratory birds are starting to arrive too. Let me know if you want to join for some birdwatching!",
#    'id': 'Event_Communication_1'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:10:00',
#    'content': "Hey The Lookout, The Intern here! I'd absolutely love to join you for birdwatching this weekend! Those dolphins sound amazing. What time were you thinking? I'll bring my new binoculars that Mrs. Money helped me pick out.",
#    'id': 'Event_Communication_2'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:13:00',
#    'content': "Sam, it's Kelly! Let's meet at Sunrise Point at 7 AM for birdwatching. Bring your new binoculars and some water. I've heard there might be some rare shorebirds passing through this weekend. Can't wait!",
#    'id': 'Event_Communication_3'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:16:00',
#    'content': "Mrs. Money, it's The Intern. Just checking in to see what tasks you need help with today. Also, I'll be birdwatching with The Lookout this weekend. Should I reschedule if you need me for anything?",
#    'id': 'Event_Communication_5'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:19:00',
#    'content': "Boss, it's Mrs. Money. I've reviewed our operational funding for the upcoming projects. Need to discuss allocation priorities before our meeting with The Middleman next week. Are you available tomorrow afternoon?",
#    'id': 'Event_Communication_6'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:21:00',
#    'content': "Mrs. Money, this is Boss. I'm available tomorrow at 3 PM to discuss funding allocations. Bring the updated projections for our tourism ventures. We need to ensure everything looks legitimate before meeting The Middleman next week.",
#    'id': 'Event_Communication_7'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:24:00',
#    'content': "Boss, Mrs. Money here. I'll bring the updated projections for tomorrow at 3PM. I've noted some interesting opportunities near Nemo Reef in our tourism portfolio. Should we discuss allocating additional resources there specifically?",
#    'id': 'Event_Communication_8'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:26:00',
#    'content': "Middleman, this is Boss. I'd like to move our meeting forward to discuss some promising opportunities near Nemo Reef. My accountant has identified potential for expansion there. Can you meet earlier than planned?",
#    'id': 'Event_Communication_9'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:29:00',
#    'content': "Boss, this is The Middleman. I can meet earlier as requested. Nemo Reef discussion is timely - I've noted increased interest in that area. Have some council updates that might benefit your expansion plans. When and where?",
#    'id': 'Event_Communication_10'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:32:00',
#    'content': "Middleman, this is Boss. Let's meet tomorrow at 4PM at the usual spot by the marina. I'll bring the tourism portfolio with Nemo Reef projections. Curious about those council updates that might help our expansion.",
#    'id': 'Event_Communication_11'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:34:00',
#    'content': "Boss, this is Middleman. I'll be at the marina tomorrow at 4PM. Just reviewed some council documents - there's a potential loophole in Nemo Reef protection zones we can discuss. I'll bring the relevant paperwork.",
#    'id': 'Event_Communication_12'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:50:00',
#    'content': "Ahoy, this is the luxury yacht Serenity. I've heard you're familiar with these waters. My owner is looking for premium diving spots. Heard about Nemo Reef, but understand it's restricted. Any comparable alternatives you could recommend?",
#    'id': 'Event_Communication_13'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:52:00',
#    'content': 'Serenity, this is Mako. For premium diving comparable to Nemo Reef, try Azure Cove just 3 miles south. Less restricted, similar coral formations, and better visibility. We just documented excellent conditions there yesterday during our coastal survey.',
#    'id': 'Event_Communication_15'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:53:00',
#    'content': "Reef Guardian, this is Serenity. My owner is quite disappointed about Nemo Reef restrictions. Are there any special permits available for private vessels to access certain sections? We're willing to follow strict conservation guidelines.",
#    'id': 'Event_Communication_16'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 08:59:00',
#    'content': "Harbor Master to Mako. Confirming your 07:00 departure today with Remora for Sailors Team's reconnaissance. Please remember to return before sunset and maintain distance from protected marine areas. Safe journey.",
#    'id': 'Event_Communication_17'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:02:00',
#    'content': 'Davis, Mako here. Just completed documentation of our sites. Coral Point has excellent visibility but too exposed for filming. Dolphin Bay offers privacy but those currents will be challenging for equipment setup. Heading back to Himark as scheduled.',
#    'id': 'Event_Communication_20'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:49:00',
#    'content': "Mrs. Money, this is Boss. After speaking with The Middleman, I'm confident about our Nemo Reef opportunity. He mentioned a potential loophole in protection zones. Let's discuss this during our 3PM meeting along with funding allocations.",
#    'id': 'Event_Communication_21'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:52:00',
#    'content': "Middleman, it's Mrs. Money. I've prepared those financial projections we discussed. Particularly interested in your thoughts on that Nemo Reef loophole before my meeting with Boss tomorrow. Available to talk this evening?",
#    'id': 'Event_Communication_22'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:55:00',
#    'content': "Serenity, Reef Guardian here. I understand your disappointment, but Nemo Reef is strictly protected without special access permits. However, we can recommend several equally beautiful non-protected areas nearby. We're observing increased tourism pressure lately, which is why enforcement remains strict.",
#    'id': 'Event_Communication_24'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:58:00',
#    'content': "Himark Harbor, this is luxury yacht Serenity. We're planning to anchor for the evening. Can you confirm availability for a 120-foot vessel requiring premium berth services? My owner would appreciate any local recommendations for exclusive dining options as well.",
#    'id': 'Event_Communication_26'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 09:59:00',
#    'content': "Himark Harbor to Serenity. Premium berth confirmed for your 120-foot vessel. Recommend 'The Pearl' for exclusive dining - waterfront views and renowned seafood. Harbor staff will assist with your berthing upon arrival.",
#    'id': 'Event_Communication_28'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:43:00',
#    'content': "Attention Remora, this is Paackland Harbor. We've observed your vessel approaching Nemo Reef's protected inner boundary. Please maintain appropriate distance from restricted zones as per maritime conservation regulations. Acknowledge receipt.",
#    'id': 'Event_Communication_30'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:46:00',
#    'content': "Paackland Harbor, this is Remora. Acknowledging your warning. We'll maintain proper distance from Nemo Reef's protected areas. Currently surveying locations with Rodriguez for Sailor Shifts Team's upcoming video shoot. Will respect all conservation regulations.",
#    'id': 'Event_Communication_32'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:48:00',
#    'content': 'This is Paackland Harbor to Oceanus City Council. Reporting increased tourism vessel activity near protected areas, specifically Nemo Reef. Have issued standard reminders about conservation regulations. Recommend additional signage or patrol consideration for upcoming tourism season.',
#    'id': 'Event_Communication_35'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:51:00',
#    'content': "Liam, this is Oceanus City Council. We've received reports from Paackland Harbor about increased tourism vessels near Nemo Reef. Please coordinate with harbor masters to enhance conservation patrols and consider temporary additional signage for protected areas.",
#    'id': 'Event_Communication_37'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:53:00',
#    'content': 'Mrs. Money, this is The Middleman. I can meet this evening to discuss the Nemo Reef loophole before your meeting with Boss. Council just flagged increased vessel activity there - perfect timing for our plans. 7PM at the cafe?',
#    'id': 'Event_Communication_39'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:55:00',
#    'content': "The Middleman, it's Mrs. Money. 7PM at the cafe works perfectly. I'll bring those financial projections on the Nemo Reef opportunity. I've also identified potential funding sources that won't raise flags with regulators.",
#    'id': 'Event_Communication_40'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:56:00',
#    'content': "Council, this is Liam Thorne. I've reviewed the Nemo Reef reports and am coordinating with harbor masters as requested. Will implement additional signage by tomorrow and increase patrols this weekend. Sending full action plan by end of day.",
#    'id': 'Event_Communication_43'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 10:58:00',
#    'content': "Paackland Harbor, this is Oceanus City Council. We've received your report and are taking action. Liam Thorne is coordinating additional signage installation tomorrow and increased patrols this weekend. Full action plan forthcoming. Thank you for your vigilance.",
#    'id': 'Event_Communication_45'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:01:00',
#    'content': "Reef Guardian, Paackland Harbor here. We're seeing increased tourism activity near Nemo Reef's protected zones. Please increase monitoring patrols in that area over the next 48 hours. Oceanus Council is adding signage tomorrow. Confirm when possible.",
#    'id': 'Event_Communication_48'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:02:00',
#    'content': "Himark Harbor, this is Marlin. Another day with half-empty nets while burning through fuel that costs double what it did last year. These new catch quotas are killing us local fishermen. Conservation sounds nice until families can't put food on the table.",
#    'id': 'Event_Communication_50'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:03:00',
#    'content': "Himark Harbor to Marlin. We understand your concerns about the catch quotas. We've noted your feedback and will relay it to the Oceanus City Council at our next meeting. Is there anything else you need from harbor services today?",
#    'id': 'Event_Communication_51'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:06:00',
#    'content': 'Oceanus City Council, this is Marlin. These new regulations are destroying our livelihood. Fuel costs doubled while catch limits halved. Five generations of my family fished these waters. Now we can barely break even. Please reconsider before there are no local fishermen left.',
#    'id': 'Event_Communication_53'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:09:00',
#    'content': "Marlin, this is Oceanus City Council. We hear your concerns about the fishing regulations. Let's schedule a community forum next week to discuss sustainable solutions that balance conservation needs with fishermen's livelihoods. Please confirm your availability.",
#    'id': 'Event_Communication_54'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:10:00',
#    'content': "Mako to Remora. How's visibility in your sector? We've documented good conditions at Azure Cove and challenging currents at Dolphin Bay. Planning to rendezvous at Himark's south dock at 16:00 as scheduled. Over.",
#    'id': 'Event_Communication_59'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 11:40:00',
#    'content': "Reef Guardian, Green Guardians HQ here. We've noted increased tourism vessel activity near protected areas, especially around Nemo Reef. Please maintain extra vigilance over the next two weeks and report any regulation violations immediately.",
#    'id': 'Event_Communication_62'},
#   {'type': 'Event',
#    'sub_type': 'Communication',
#    'label': 'Communication',
#    'timestamp': '2040-10-01 12:26:00',
# ...
#    'target': 'Relationship_Coordinates_411'},
#   {'id': '1273',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Seawatch',
#    'target': 'Event_Communication_679'},
#   {'id': '1280',
#    'is_inferred': True,
#    'source': 'Seawatch',
#    'target': 'Relationship_AccessPermission_489'},
#   {'id': '1275',
#    'is_inferred': True,
#    'source': 'Seawatch',
#    'target': 'Event_Assessment_786'},
#   {'id': '1276',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Seawatch',
#    'target': 'Event_Communication_787'},
#   {'id': '1277',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Seawatch',
#    'target': 'Event_Communication_793'},
#   {'id': '1278',
#    'is_inferred': True,
#    'source': 'Seawatch',
#    'target': 'Event_Monitoring_909'},
#   {'id': '1279',
#    'is_inferred': True,
#    'source': 'Seawatch',
#    'target': 'Event_Monitoring_934'},
#   {'id': '1281',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_105'},
#   {'id': '1356',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Reports_51'},
#   {'id': '1284',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Collaborate_108'},
#   {'id': '1286',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_109'},
#   {'id': '1288',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_111'},
#   {'id': '1289',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_208'},
#   {'id': '1291',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_209'},
#   {'id': '1292',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_VesselMovement_242'},
#   {'id': '1293',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_243'},
#   {'id': '1294',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_414'},
#   {'id': '1287',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Coordinates_251'},
#   {'id': '1296',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_415'},
#   {'id': '1297',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_VesselMovement_624'},
#   {'id': '1298',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Assessment_625'},
#   {'id': '1299',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Collaborate_626'},
#   {'id': '1301',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_627'},
#   {'id': '1300',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Coordinates_401'},
#   {'id': '1303',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Enforcement_666'},
#   {'id': '1306',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_VesselMovement_670'},
#   {'id': '1307',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_716'},
#   {'id': '1308',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_441'},
#   {'id': '1309',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_731'},
#   {'id': '1312',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_733'},
#   {'id': '1305',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_444'},
#   {'id': '1321',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Reports_447'},
#   {'id': '1317',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_737'},
#   {'id': '1322',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_742'},
#   {'id': '1327',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_455'},
#   {'id': '1328',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_751'},
#   {'id': '1326',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_752'},
#   {'id': '1330',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Suspicious_457'},
#   {'id': '1333',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_922'},
#   {'id': '1334',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_929'},
#   {'id': '1335',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_585'},
#   {'id': '1331',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_VesselMovement_931'},
#   {'id': '1337',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_932'},
#   {'id': '1332',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_588'},
#   {'id': '1339',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_934'},
#   {'id': '1341',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Enforcement_952'},
#   {'id': '1343',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Reports_604'},
#   {'id': '1344',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_960'},
#   {'id': '1345',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_971'},
#   {'id': '1346',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Collaborate_972'},
#   {'id': '1347',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Coordinates_614'},
#   {'id': '1348',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_AccessPermission_615'},
#   {'id': '1349',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_974'},
#   {'id': '1351',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_976'},
#   {'id': '1352',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Relationship_Coordinates_616'},
#   {'id': '1353',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'EcoVigil',
#    'target': 'Event_Communication_977'},
#   {'id': '1342',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Monitoring_995'},
#   {'id': '1315',
#    'is_inferred': True,
#    'source': 'EcoVigil',
#    'target': 'Event_Assessment_996'},
#   {'id': '1357',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_69'},
#   {'id': '1358',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_74'},
#   {'id': '1359',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_79'},
#   {'id': '1361',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Assessment_172'},
#   {'id': '1362',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_173'},
#   {'id': '1363',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Enforcement_193'},
#   {'id': '1365',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_213'},
#   {'id': '1367',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_VesselMovement_242'},
#   {'id': '1368',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_243'},
#   {'id': '1382',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_266'},
#   {'id': '1370',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_267'},
#   {'id': '1398',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Suspicious_145'},
#   {'id': '1373',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_270'},
#   {'id': '1375',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_272'},
#   {'id': '1377',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_299'},
#   {'id': '1378',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_320'},
#   {'id': '1379',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_410'},
#   {'id': '1380',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Coordinates_252'},
#   {'id': '1383',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_435'},
#   {'id': '1372',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Coordinates_269'},
#   {'id': '1386',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_VesselMovement_483'},
#   {'id': '1387',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_484'},
#   {'id': '1396',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Suspicious_293'},
#   {'id': '1389',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_485'},
#   {'id': '1390',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_VesselMovement_563'},
#   {'id': '1393',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_565'},
#   {'id': '1394',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Assessment_567'},
#   {'id': '1397',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_574'},
#   {'id': '1400',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_674'},
#   {'id': '1401',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Reports_408'},
#   {'id': '1403',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Suspicious_410'},
#   {'id': '1404',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_677'},
#   {'id': '1405',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Enforcement_693'},
#   {'id': '1422',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_AccessPermission_421'},
#   {'id': '1408',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_777'},
#   {'id': '1410',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_849'},
#   {'id': '1413',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_897'},
#   {'id': '1414',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_VesselMovement_904'},
#   {'id': '1415',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_AccessPermission_569'},
#   {'id': '1418',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Relationship_Reports_572'},
#   {'id': '1419',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_909'},
#   {'id': '1420',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_911'},
#   {'id': '1423',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_914'},
#   {'id': '1424',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_922'},
#   {'id': '1425',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Monitoring_934'},
#   {'id': '1426',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Sentinel',
#    'target': 'Event_Communication_965'},
#   {'id': '1421',
#    'is_inferred': True,
#    'source': 'Sentinel',
#    'target': 'Event_Assessment_973'},
#   {'id': '1428',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_TourActivity_96'},
#   {'id': '1430',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_97'},
#   {'id': '1431',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_136'},
#   {'id': '1432',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_TourActivity_140'},
#   {'id': '1433',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_141'},
#   {'id': '1434',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_VesselMovement_242'},
#   {'id': '1435',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_Monitoring_243'},
#   {'id': '1437',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_654'},
#   {'id': '1438',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_VesselMovement_806'},
#   {'id': '1436',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_TourActivity_807'},
#   {'id': '1440',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Relationship_AccessPermission_502'},
#   {'id': '1441',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_808'},
#   {'id': '1442',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Event_TourActivity_816'},
#   {'id': '1429',
#    'is_inferred': True,
#    'source': 'Osprey',
#    'target': 'Relationship_Coordinates_509'},
#   {'id': '1444',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Osprey',
#    'target': 'Event_Communication_817'},
#   {'id': '1445',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Defender',
#    'target': 'Event_Communication_165'},
#   {'id': '1446',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_Monitoring_168'},
#   {'id': '1447',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Defender',
#    'target': 'Event_Communication_169'},
#   {'id': '1448',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_VesselMovement_242'},
#   {'id': '1449',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_Monitoring_243'},
#   {'id': '1450',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_Monitoring_688'},
#   {'id': '1451',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Relationship_Coordinates_418'},
#   {'id': '1452',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Defender',
#    'target': 'Event_Communication_689'},
#   {'id': '1453',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_Enforcement_769'},
#   {'id': '1454',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Defender',
#    'target': 'Event_Communication_855'},
#   {'id': '1455',
#    'is_inferred': True,
#    'source': 'Defender',
#    'target': 'Event_Monitoring_934'},
#   {'id': '1456',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Defender',
#    'target': 'Event_Communication_999'},
#   {'id': '1457',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Northern Light',
#    'target': 'Event_Communication_228'},
#   {'id': '1458',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Northern Light',
#    'target': 'Event_Communication_230'},
#   {'id': '1459',
#    'is_inferred': True,
#    'source': 'Northern Light',
#    'target': 'Relationship_Unfriendly_130'},
#   {'id': '1460',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Northern Light',
#    'target': 'Event_Communication_234'},
#   {'id': '1461',
#    'is_inferred': True,
#    'source': 'Northern Light',
#    'target': 'Event_VesselMovement_634'},
#   {'id': '1462',
#    'type': 'sent',
#    'is_inferred': False,
#    'source': 'Northern Light',
#    'target': 'Event_Communication_635'},
#   {'id': '1463',
#    'is_inferred': True,
#    'source': 'Northern Light',
#    'target': 'Relationship_AccessPermission_392'},
#   ...]}

# %%
nodes_type = schema['schema']['nodes'].keys()

# %%
nodes_type
# Out:
# dict_keys(['Entity', 'Event', 'Relationship'])

# %%
# I need all of the nodes that are of type 'entity'
entity_nodes = []
